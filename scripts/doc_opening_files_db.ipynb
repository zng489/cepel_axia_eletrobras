# %% [markdown]
# ```
# import pandas as pd
#
# # Define the path to the XLSX file
# file_path = "files/OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 2 (Avançada)(1-6).xlsx"
#
# # Read the XLSX file into a DataFrame
# df = pd.read_excel(file_path)
# ```

# %%
import pandas as pd
import os

# Define the directory where the files are located
directory = "files"

# List of file names (replace placeholders with actual file names)
file_names = [
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 0 (Identificação)(1-5).xlsx",
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 1 (Geral)(1-6).xlsx",  # Replace with actual file name
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 2 (Avançada)(1-6).xlsx",  # Replace with actual file name
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 3 (Interface DevOps)(1-6).xlsx"   # Replace with actual file name
]

# Dictionary to store DataFrames for each file
dataframes = {}

# Read each file into a separate DataFrame
for file_name in file_names:
    file_path = os.path.join(directory, file_name)
    try:
        df = pd.read_excel(file_path)
        dataframes[file_name] = df
        print("dataframes['{}'] = df".format(file_name))  # Print the variable name and DataFrame
    except FileNotFoundError:
        print(f"File {file_name} not found at {file_path}")
    except Exception as e:
        print(f"Error reading {file_name}: {str(e)}")

# Now you can access each DataFrame using the dictionary
# Example: dataframes['OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 2 (Avançada)(1-6).xlsx']
# Out:
# dataframes['OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 0 (Identificação)(1-5).xlsx'] = df
# dataframes['OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 1 (Geral)(1-6).xlsx'] = df
# dataframes['OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 2 (Avançada)(1-6).xlsx'] = df
# dataframes['OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 3 (Interface DevOps)(1-6).xlsx'] = df

# %%
dataframes['OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 0 (Identificação)(1-5).xlsx']
# Out:
#    ID      Hora de início   Hora de conclusão                Email  \
# 0   1 2026-02-02 11:05:31 2026-02-02 11:07:18     0361934@cepel.br
# 1   2 2026-02-02 14:22:27 2026-02-02 14:23:43  felipedias@cepel.br
# 2   3 2026-02-03 05:16:19 2026-02-03 05:18:20     0361680@cepel.br
# 3   4 2026-02-03 08:32:17 2026-02-03 08:33:26        laao@cepel.br
# 4   5 2026-02-20 07:39:48 2026-02-20 07:45:46     0362504@cepel.br
#
#                              Nome  Hora da última modificação  \
# 0                   Alberto Pavim                         NaN
# 1  Felipe Dias de Rezende Machado                         NaN
# 2                    Djalma Silva                         NaN
# 3  Luiz Antônio Alves de Oliveira                         NaN
# 4                      Zhang Yuan                         NaN
#
#   Favor inserir seu nome completo. Favor inserir seu email (@cepel.br).  \
# 0             Alberto Xavier Pavim               alberto.pavim@cepel.br
# ...

# %%
dataframes['OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 1 (Geral)(1-6).xlsx']
# Out:
#    ID      Hora de início   Hora de conclusão                Email  \
# 0   2 2026-02-02 13:20:20 2026-02-02 13:27:28     0361934@cepel.br
# 1   3 2026-02-02 14:25:20 2026-02-02 14:41:39  felipedias@cepel.br
# 2   4 2026-02-03 05:18:40 2026-02-03 05:35:49     0361680@cepel.br
# 3   5 2026-02-03 08:15:04 2026-02-03 08:31:15        laao@cepel.br
# 4   6 2026-02-20 07:46:03 2026-02-20 08:02:27     0362504@cepel.br
# 5   7 2026-02-23 09:40:33 2026-02-23 15:04:12     0361532@cepel.br
#
#                              Nome  Hora da última modificação  \
# 0                   Alberto Pavim                         NaN
# 1  Felipe Dias de Rezende Machado                         NaN
# 2                    Djalma Silva                         NaN
# 3  Luiz Antônio Alves de Oliveira                         NaN
# 4                      Zhang Yuan                         NaN
# 5               Jonathan Cabreira                         NaN
#
# ...

# %%
dataframes['OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 2 (Avançada)(1-6).xlsx']
# Out:
#    ID      Hora de início   Hora de conclusão                Email  \
# 0   1 2026-02-02 13:35:33 2026-02-02 13:48:49     0361934@cepel.br
# 1   2 2026-02-02 14:44:00 2026-02-02 14:49:45  felipedias@cepel.br
# 2   3 2026-02-03 05:36:07 2026-02-03 05:44:39     0361680@cepel.br
# 3   4 2026-02-03 08:41:28 2026-02-03 08:50:20        laao@cepel.br
# 4   5 2026-02-20 08:02:37 2026-02-20 08:28:43     0362504@cepel.br
# 5   6 2026-02-23 09:40:39 2026-02-23 14:15:06     0361532@cepel.br
#
#                              Nome  Hora da última modificação  \
# 0                   Alberto Pavim                         NaN
# 1  Felipe Dias de Rezende Machado                         NaN
# 2                    Djalma Silva                         NaN
# 3  Luiz Antônio Alves de Oliveira                         NaN
# 4                      Zhang Yuan                         NaN
# 5               Jonathan Cabreira                         NaN
#
# ...

# %%
dataframes['OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 3 (Interface DevOps)(1-6).xlsx']
# Out:
#    ID      Hora de início   Hora de conclusão                Email  \
# 0   1 2026-02-02 13:51:53 2026-02-02 14:09:32     0361934@cepel.br
# 1   2 2026-02-02 14:53:07 2026-02-02 15:02:20  felipedias@cepel.br
# 2   3 2026-02-03 05:44:54 2026-02-03 05:59:35     0361680@cepel.br
# 3   4 2026-02-03 08:51:12 2026-02-03 09:17:01        laao@cepel.br
# 4   5 2026-02-20 08:28:54 2026-02-20 08:35:55     0362504@cepel.br
# 5   6 2026-02-23 14:15:22 2026-02-23 14:27:34     0361532@cepel.br
#
#                              Nome  Hora da última modificação  \
# 0                   Alberto Pavim                         NaN
# 1  Felipe Dias de Rezende Machado                         NaN
# 2                    Djalma Silva                         NaN
# 3  Luiz Antônio Alves de Oliveira                         NaN
# 4                      Zhang Yuan                         NaN
# 5               Jonathan Cabreira                         NaN
#
#              Windows NT Server   Windows 10/11  \
# ...

# %%
import pandas as pd
import sqlite3
import os

# Define the directory where the files are located
directory = "files"

# List of file names
file_names = [
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 0 (Identificação)(1-5).xlsx",
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 1 (Geral)(1-6).xlsx",
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 2 (Avançada)(1-6).xlsx",
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 3 (Interface DevOps)(1-6).xlsx"
]

# Create a connection to an SQLite database (this will create a new database if it doesn't exist)
db_path = "cepel_data.db"
conn = sqlite3.connect(db_path)
print(f"Connected to SQLite database at {db_path}")

# Read each Excel file and load it into the SQLite database as a separate table
for file_name in file_names:
    file_path = os.path.join(directory, file_name)
    try:
        # Read the Excel file into a pandas DataFrame
        df = pd.read_excel(file_path)
        
        # Create a table name from the file name (remove special characters and spaces)
        table_name = file_name.replace(" ", "_").replace("(", "").replace(")", "").replace("-", "_").split(".")[0]
        
        # Write the DataFrame to the SQLite database as a table
        df.to_sql(table_name, conn, if_exists='replace', index=False)
        print(f"Successfully loaded {file_name} into table {table_name}")
    except FileNotFoundError:
        print(f"File {file_name} not found at {file_path}")
    except Exception as e:
        print(f"Error processing {file_name}: {str(e)}")
# Out:
# Connected to SQLite database at cepel_data.db
# Successfully loaded OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 0 (Identificação)(1-5).xlsx into table OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_0_Identificação1_5
# Successfully loaded OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 1 (Geral)(1-6).xlsx into table OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_1_Geral1_6
# Successfully loaded OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 2 (Avançada)(1-6).xlsx into table OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_2_Avançada1_6
# Successfully loaded OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 3 (Interface DevOps)(1-6).xlsx into table OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_3_Interface_DevOps1_6

# %%
import pandas as pd
import sqlite3
import os

# Define the directory where the files are located
directory = "files"

# List of file names
file_names = [
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 0 (Identificação)(1-5).xlsx",
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 1 (Geral)(1-6).xlsx",
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 2 (Avançada)(1-6).xlsx",
    "OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 3 (Interface DevOps)(1-6).xlsx"
]

# Create or connect to the SQLite database
db_path = "cepel_data.db"
conn = sqlite3.connect(db_path)
print(f"Connected to SQLite database at {db_path}")

# Read each Excel file and load it into the SQLite database as a separate table
for file_name in file_names:
    file_path = os.path.join(directory, file_name)
    try:
        # Read the Excel file into a pandas DataFrame
        df = pd.read_excel(file_path)
        
        # Create a table name from the file name (remove special characters and spaces)
        table_name = file_name.replace(" ", "_").replace("(", "").replace(")", "").replace("-", "_").split(".")[0]
        
        # Write the DataFrame to the SQLite database as a table
        df.to_sql(table_name, conn, if_exists='replace', index=False)
        print(f"Successfully loaded {file_name} into table {table_name}")
    except FileNotFoundError:
        print(f"File {file_name} not found at {file_path}")
    except Exception as e:
        print(f"Error processing {file_name}: {str(e)}")

# Check all tables in the database to confirm their names
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()
print("\nTables in the database:")
for table in tables:
    print(table[0])
# Out:
# Connected to SQLite database at cepel_data.db
# Successfully loaded OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 0 (Identificação)(1-5).xlsx into table OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_0_Identificação1_5
# Successfully loaded OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 1 (Geral)(1-6).xlsx into table OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_1_Geral1_6
# Successfully loaded OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 2 (Avançada)(1-6).xlsx into table OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_2_Avançada1_6
# Successfully loaded OLD - Composição do Stack Tecnológico de Dados no Cepel_Parte 3 (Interface DevOps)(1-6).xlsx into table OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_3_Interface_DevOps1_6
#
# Tables in the database:
# OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_0_Identificação1_5
# ...

# %%
for table in tables:
    print(table)
# Out:
# ('OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_0_Identificação1_5',)
# ('OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_1_Geral1_6',)
# ('OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_2_Avançada1_6',)
# ('OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_3_Interface_DevOps1_6',)

# %%
# Example: Query the first few rows from the first available table (if any)
if tables:
    example_table = tables[0][0]  # Take the first table name from the list
    print(f"\nQuerying the first few rows from table: {example_table}")
# Out:
# Querying the first few rows from table: OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_0_Identificação1_5

# %% [markdown]
# ```
# Você cria:
#
# conn → conexão com o banco
#
# cursor → objeto que executa comandos SQL
#
# Ele executa SQL diretamente no arquivo do banco, sem HTTP, sem JSON, sem requisição externa.
# ```

# %%
# Example: Query the first few rows from the first available table (if any)
if tables:
    example_table = tables[0][0]  # Take the first table name from the list
    try:
        cursor.execute(f"SELECT * FROM {example_table} LIMIT 5")
        rows = cursor.fetchall()
        columns = [description[0] for description in cursor.description]
        print(f"\nFirst 5 rows from table {example_table}:")
        print(columns)
        for row in rows:
            print(row)
    except Exception as e:
        print(f"Error querying table {example_table}: {str(e)}")
else:
    print("\nNo tables found in the database. Please check if the files were loaded correctly.")
# Out:
# First 5 rows from table OLD___Composição_do_Stack_Tecnológico_de_Dados_no_Cepel_Parte_0_Identificação1_5:
# ['ID', 'Hora de início', 'Hora de conclusão', 'Email', 'Nome', 'Hora da última modificação', 'Favor inserir seu\xa0nome completo.', 'Favor inserir seu\xa0email\xa0(@cepel.br).', 'Em qual\xa0departamento\xa0do Cepel você está alocado?', 'Favor apontar sua\xa0faixa etária.', 'Favor apontar o seu\xa0tempo de casa\xa0no Cepel.', 'Favor apontar seu maior nível de\xa0formação educacional.', 'Há quanto tempo você já\xa0programa\xa0/\xa0desenvolve sistemas?', 'Há quanto tempo você já\xa0trabalha com dados\xa0(governança, engenharia, ciência, ou análise de dados)?']
# (1, '2026-02-02 11:05:31', '2026-02-02 11:07:18', '0361934@cepel.br', 'Alberto Pavim', None, 'Alberto Xavier Pavim', 'alberto.pavim@cepel.br', 'DT/DID - Depto de IA e Dados', '45-54 anos', 'Menos de 1 ano', 'Doutorado', '5-10 anos', '3-5 anos')
# ...

# %% [markdown]
# # I've got db and reading as dataframe

# %%
# Example: Query the first few rows from the first available table (if any) and return as DataFrame
if tables:
    example_table = tables[0][0]  # Take the first table name from the list
    try:
        # Use pandas to directly read the SQL query result into a DataFrame
        df = pd.read_sql_query(f"SELECT * FROM {example_table} LIMIT 5", conn)
        print(f"\nFirst 5 rows from table {example_table} as a DataFrame:")
        display(df)  # Use display() for better formatting in Jupyter Notebook
    except Exception as e:
        print(f"Error querying table {example_table}: {str(e)}")
else:
    print("\nNo tables found in the database. Please check if the files were loaded correctly.")

# %% [markdown]
# # Analysing

# %%
example_table = tables[0][0]  # Take the first table name from the list

df = pd.read_sql_query(f"SELECT * FROM {example_table} LIMIT 5", conn)
print(f"\nFirst 5 rows from table {example_table} as a DataFrame:")
display(df)  # Use display() for better formatting in Jupyter Notebook

# %%
example_table = tables[1][0]  # Take the first table name from the list

df = pd.read_sql_query(f"SELECT * FROM {example_table} LIMIT 5", conn)
print(f"\nFirst 5 rows from table {example_table} as a DataFrame:")
display(df)  # Use display() for better formatting in Jupyter Notebook
